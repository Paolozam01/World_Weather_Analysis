# %%
# Dependencies 
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
import random
from citipy import citipy
from datetime import datetime 
from config import weather_api_key
import requests
import time
from scipy.stats import linregress
import gmaps
from config import g_key

# %%
# Create list for weather data
city_data = []

# Print the beginning of the logging
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Create basic url for API
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 775

# %%
# Loop through city Lists 
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 
    if (i % 50 == 0 and i >= 50):
        set_count += 1 
        record_count = 1 
    
    # Create URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log URL, set, and record numbers for each city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1

# Make an API request for each city 
    try:
       
        # Parse the JSON data
        city_weather = requests.get(city_url).json()

        # Compile needed data
        city_city = city.title()
        city_country = city_weather['sys']['country']
        city_date = datetime.utcfromtimestamp(city_weather['dt']).strftime('%Y-%m-%d %H:%M:%S')
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_hum = city_weather['main']['humidity']
        city_cloud = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_desc = city_weather['weather'][0]['description']
        # Fill City Data list 
        city_data.append({"City": city_city,
                         "Country": city_country,
                         "Date": city_date,
                         "Lat": city_lat,
                         "Lng": city_lng,
                         "Max Temp": city_max_temp,
                         "Humidity": city_hum,
                         "Cloudiness": city_cloud,
                         "Wind Speed": city_wind,
                         "Current Description": city_desc,
                         })
        
    #If an error occurs
    except: 
        print("City not found. Skipping")
        pass

    # Complete Data Retrieval    
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | upernavik
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | cabo san lucas
# Processing Record 4 of Set 1 | penzance
# Processing Record 5 of Set 1 | krasnoselkup
# Processing Record 6 of Set 1 | kavieng
# Processing Record 7 of Set 1 | victoria
# Processing Record 8 of Set 1 | busselton
# Processing Record 9 of Set 1 | paamiut
# Processing Record 10 of Set 1 | rikitea
# Processing Record 11 of Set 1 | chokurdakh
# Processing Record 12 of Set 1 | nikolskoye
# Processing Record 13 of Set 1 | angra
# City not found. Skipping
# Processing Record 14 of Set 1 | bredasdorp
# Processing Record 15 of Set 1 | hilo
# Processing Record 16 of Set 1 | adrar
# Processing Record 17 of Set 1 | codrington
# Processing Record 18 of Set 1 | mataura
# Processing Record 19 of Set 1 | bien hoa
# Processing Record 20 of Set 1 | ust-tsilma
# Processing Record 21 of Set 1 | kamenskoye
# City not found. Skipping
# Processing Record 22 of Set 1 | hasaki
# Processing Record 23 of Set 1 | luderitz
# Processing Record 24 of Set 1 | mana
# Processing Record 25 of Set 1 | illoqqortoormiut
# City not found. Skipping
# Processing Record 26 of Set 1 | jamestown
# Processing Record 27 of Set 1 | vaitupu
# City not found. Skipping
# Processing Record 28 of Set 1 | taolanaro
# City not found. Skipping
# Processing Record 29 of Set 1 | yellowknife
# Processing Record 30 of Set 1 | avarua
# Processing Record 31 of Set 1 | saint george
# Processing Record 32 of Set 1 | santa maria
# Processing Record 33 of Set 1 | klaksvik
# Processing Record 34 of Set 1 | san patricio
# Processing Record 35 of Set 1 | provideniya
# Processing Record 36 of Set 1 | port elizabeth
# Processing Record 37 of Set 1 | amderma
# City not found. Skipping
# Processing Record 38 of Set 1 | nanortalik
# Processing Record 39 of Set 1 | hermanus
# Processing Record 40 of Set 1 | sataua
# City not found. Skipping
# Processing Record 41 of Set 1 | iqaluit
# Processing Record 42 of Set 1 | la asuncion
# Processing Record 43 of Set 1 | souillac
# Processing Record 44 of Set 1 | constitucion
# Processing Record 45 of Set 1 | puerto ayora
# Processing Record 46 of Set 1 | sogamoso
# Processing Record 47 of Set 1 | joensuu
# Processing Record 48 of Set 1 | mocuba
# Processing Record 49 of Set 1 | port alfred
# Processing Record 50 of Set 1 | arraial do cabo
# Processing Record 1 of Set 2 | ribeira grande
# Processing Record 2 of Set 2 | muros
# Processing Record 3 of Set 2 | acapulco
# Processing Record 4 of Set 2 | new norfolk
# Processing Record 5 of Set 2 | pemangkat
# Processing Record 6 of Set 2 | hobart
# Processing Record 7 of Set 2 | havre-saint-pierre
# Processing Record 8 of Set 2 | tsihombe
# City not found. Skipping
# Processing Record 9 of Set 2 | gushikawa
# Processing Record 10 of Set 2 | kapaa
# Processing Record 11 of Set 2 | longyearbyen
# Processing Record 12 of Set 2 | san matias
# Processing Record 13 of Set 2 | newport
# Processing Record 14 of Set 2 | rongcheng
# Processing Record 15 of Set 2 | sanchor
# Processing Record 16 of Set 2 | yangcun
# Processing Record 17 of Set 2 | bethel
# Processing Record 18 of Set 2 | safford
# Processing Record 19 of Set 2 | marienburg
# Processing Record 20 of Set 2 | linhares
# Processing Record 21 of Set 2 | price
# Processing Record 22 of Set 2 | atuona
# Processing Record 23 of Set 2 | butaritari
# Processing Record 24 of Set 2 | ketchikan
# Processing Record 25 of Set 2 | bluff
# Processing Record 26 of Set 2 | sitka
# Processing Record 27 of Set 2 | ilulissat
# Processing Record 28 of Set 2 | albany
# Processing Record 29 of Set 2 | sinnamary
# Processing Record 30 of Set 2 | batemans bay
# Processing Record 31 of Set 2 | kalabo
# Processing Record 32 of Set 2 | dois vizinhos
# Processing Record 33 of Set 2 | kruisfontein
# Processing Record 34 of Set 2 | udachnyy
# Processing Record 35 of Set 2 | fairbanks
# Processing Record 36 of Set 2 | poum
# Processing Record 37 of Set 2 | punta arenas
# Processing Record 38 of Set 2 | lebu
# Processing Record 39 of Set 2 | sao filipe
# Processing Record 40 of Set 2 | vaini
# Processing Record 41 of Set 2 | talnakh
# Processing Record 42 of Set 2 | georgetown
# Processing Record 43 of Set 2 | thinadhoo
# Processing Record 44 of Set 2 | douglas
# Processing Record 45 of Set 2 | tura
# Processing Record 46 of Set 2 | esperance
# Processing Record 47 of Set 2 | turukhansk
# Processing Record 48 of Set 2 | elko
# Processing Record 49 of Set 2 | escalerillas
# Processing Record 50 of Set 2 | san cristobal
# Processing Record 1 of Set 3 | mindelo
# Processing Record 2 of Set 3 | bima
# Processing Record 3 of Set 3 | tula
# Processing Record 4 of Set 3 | maxixe
# Processing Record 5 of Set 3 | verkhnevilyuysk
# Processing Record 6 of Set 3 | hithadhoo
# Processing Record 7 of Set 3 | najran
# Processing Record 8 of Set 3 | oistins
# Processing Record 9 of Set 3 | beruni
# City not found. Skipping
# Processing Record 10 of Set 3 | saint-philippe
# Processing Record 11 of Set 3 | thompson
# Processing Record 12 of Set 3 | sakaiminato
# Processing Record 13 of Set 3 | corsicana
# Processing Record 14 of Set 3 | frohnleiten
# Processing Record 15 of Set 3 | pokosnoye
# Processing Record 16 of Set 3 | blagoyevo
# Processing Record 17 of Set 3 | portland
# Processing Record 18 of Set 3 | mys shmidta
# City not found. Skipping
# Processing Record 19 of Set 3 | belmonte
# Processing Record 20 of Set 3 | dikson
# Processing Record 21 of Set 3 | tiksi
# Processing Record 22 of Set 3 | volksrust
# Processing Record 23 of Set 3 | sovetskiy
# Processing Record 24 of Set 3 | cruzeiro do sul
# Processing Record 25 of Set 3 | rawson
# Processing Record 26 of Set 3 | lazaro cardenas
# Processing Record 27 of Set 3 | coalcoman
# City not found. Skipping
# Processing Record 28 of Set 3 | keuruu
# Processing Record 29 of Set 3 | beaverlodge
# Processing Record 30 of Set 3 | cape town
# Processing Record 31 of Set 3 | cayenne
# Processing Record 32 of Set 3 | mananjary
# Processing Record 33 of Set 3 | proletariy
# Processing Record 34 of Set 3 | guerrero negro
# Processing Record 35 of Set 3 | senanga
# Processing Record 36 of Set 3 | belushya guba
# City not found. Skipping
# Processing Record 37 of Set 3 | tokmak
# Processing Record 38 of Set 3 | vao
# Processing Record 39 of Set 3 | narva-joesuu
# Processing Record 40 of Set 3 | husavik
# Processing Record 41 of Set 3 | maragogi
# Processing Record 42 of Set 3 | high rock
# Processing Record 43 of Set 3 | bathsheba
# Processing Record 44 of Set 3 | east london
# Processing Record 45 of Set 3 | novoagansk
# Processing Record 46 of Set 3 | wageningen
# Processing Record 47 of Set 3 | castro
# Processing Record 48 of Set 3 | faanui
# Processing Record 49 of Set 3 | ola
# Processing Record 50 of Set 3 | marawi
# Processing Record 1 of Set 4 | saskylakh
# Processing Record 2 of Set 4 | sorland
# Processing Record 3 of Set 4 | kupang
# Processing Record 4 of Set 4 | sabha
# Processing Record 5 of Set 4 | fortuna
# Processing Record 6 of Set 4 | shimoda
# Processing Record 7 of Set 4 | tromso
# Processing Record 8 of Set 4 | nguruka
# Processing Record 9 of Set 4 | ramachandrapuram
# Processing Record 10 of Set 4 | yen bai
# Processing Record 11 of Set 4 | kovdor
# Processing Record 12 of Set 4 | la rioja
# Processing Record 13 of Set 4 | nome
# Processing Record 14 of Set 4 | norman wells
# Processing Record 15 of Set 4 | aksarka
# Processing Record 16 of Set 4 | ampere
# Processing Record 17 of Set 4 | tazovskiy
# Processing Record 18 of Set 4 | kazachinskoye
# Processing Record 19 of Set 4 | lewistown
# Processing Record 20 of Set 4 | varhaug
# Processing Record 21 of Set 4 | port blair
# Processing Record 22 of Set 4 | lasa
# Processing Record 23 of Set 4 | kahului
# Processing Record 24 of Set 4 | torbat-e jam
# Processing Record 25 of Set 4 | hervey bay
# Processing Record 26 of Set 4 | tanjong sepat
# City not found. Skipping
# Processing Record 27 of Set 4 | lanxi
# Processing Record 28 of Set 4 | mount isa
# Processing Record 29 of Set 4 | santa fe
# Processing Record 30 of Set 4 | naze
# Processing Record 31 of Set 4 | karratha
# Processing Record 32 of Set 4 | maraba
# Processing Record 33 of Set 4 | ngukurr
# City not found. Skipping
# Processing Record 34 of Set 4 | saint-pierre
# Processing Record 35 of Set 4 | tihemetsa
# Processing Record 36 of Set 4 | barrow
# Processing Record 37 of Set 4 | dingle
# Processing Record 38 of Set 4 | nizhneyansk
# City not found. Skipping
# Processing Record 39 of Set 4 | ginda
# Processing Record 40 of Set 4 | coquimbo
# Processing Record 41 of Set 4 | los llanos de aridane
# Processing Record 42 of Set 4 | aswan
# Processing Record 43 of Set 4 | akureyri
# Processing Record 44 of Set 4 | akyab
# Processing Record 45 of Set 4 | ancud
# Processing Record 46 of Set 4 | faya
# Processing Record 47 of Set 4 | simmerath
# Processing Record 48 of Set 4 | tasiilaq
# Processing Record 49 of Set 4 | attawapiskat
# City not found. Skipping
# Processing Record 50 of Set 4 | hobyo
# Processing Record 1 of Set 5 | rabo de peixe
# Processing Record 2 of Set 5 | ayagoz
# Processing Record 3 of Set 5 | nangong
# Processing Record 4 of Set 5 | toora-khem
# Processing Record 5 of Set 5 | lebedinyy
# Processing Record 6 of Set 5 | kingman
# Processing Record 7 of Set 5 | carauari
# Processing Record 8 of Set 5 | ahipara
# Processing Record 9 of Set 5 | kodiak
# Processing Record 10 of Set 5 | rossland
# Processing Record 11 of Set 5 | cidreira
# Processing Record 12 of Set 5 | leshukonskoye
# Processing Record 13 of Set 5 | namibe
# Processing Record 14 of Set 5 | borovichi
# Processing Record 15 of Set 5 | kasongo-lunda
# Processing Record 16 of Set 5 | bani
# Processing Record 17 of Set 5 | katsuura
# Processing Record 18 of Set 5 | mar del plata
# Processing Record 19 of Set 5 | lavrentiya
# Processing Record 20 of Set 5 | mayo
# Processing Record 21 of Set 5 | severo-kurilsk
# Processing Record 22 of Set 5 | sanary-sur-mer
# Processing Record 23 of Set 5 | nguiu
# City not found. Skipping
# Processing Record 24 of Set 5 | port-cartier
# Processing Record 25 of Set 5 | sinyavino
# Processing Record 26 of Set 5 | dobryanka
# Processing Record 27 of Set 5 | hohhot
# Processing Record 28 of Set 5 | karkaralinsk
# City not found. Skipping
# Processing Record 29 of Set 5 | hermiston
# Processing Record 30 of Set 5 | alyangula
# Processing Record 31 of Set 5 | matay
# Processing Record 32 of Set 5 | hambantota
# Processing Record 33 of Set 5 | qandala
# Processing Record 34 of Set 5 | olafsvik
# Processing Record 35 of Set 5 | kristiansund
# Processing Record 36 of Set 5 | bilibino
# Processing Record 37 of Set 5 | uyemskiy
# Processing Record 38 of Set 5 | sentyabrskiy
# City not found. Skipping
# Processing Record 39 of Set 5 | tidore
# City not found. Skipping
# Processing Record 40 of Set 5 | mae sai
# Processing Record 41 of Set 5 | kiunga
# Processing Record 42 of Set 5 | ponta do sol
# Processing Record 43 of Set 5 | nizhniy tsasuchey
# Processing Record 44 of Set 5 | soe
# Processing Record 45 of Set 5 | harper
# Processing Record 46 of Set 5 | vila velha
# Processing Record 47 of Set 5 | marcona
# City not found. Skipping
# Processing Record 48 of Set 5 | broome
# Processing Record 49 of Set 5 | puerto leguizamo
# Processing Record 50 of Set 5 | labuan
# Processing Record 1 of Set 6 | bud
# Processing Record 2 of Set 6 | zhigansk
# Processing Record 3 of Set 6 | port moresby
# Processing Record 4 of Set 6 | brae
# Processing Record 5 of Set 6 | airai
# Processing Record 6 of Set 6 | makat
# Processing Record 7 of Set 6 | halifax
# Processing Record 8 of Set 6 | cheuskiny
# City not found. Skipping
# Processing Record 9 of Set 6 | cordoba
# Processing Record 10 of Set 6 | soroti
# Processing Record 11 of Set 6 | kaitangata
# Processing Record 12 of Set 6 | jieshi
# Processing Record 13 of Set 6 | samusu
# City not found. Skipping
# Processing Record 14 of Set 6 | alice springs
# Processing Record 15 of Set 6 | sur
# Processing Record 16 of Set 6 | mezen
# Processing Record 17 of Set 6 | inhambane
# Processing Record 18 of Set 6 | campo bom
# Processing Record 19 of Set 6 | yecla
# Processing Record 20 of Set 6 | port hardy
# Processing Record 21 of Set 6 | sambava
# Processing Record 22 of Set 6 | chumikan
# Processing Record 23 of Set 6 | shelburne
# Processing Record 24 of Set 6 | jiuquan
# Processing Record 25 of Set 6 | key west
# Processing Record 26 of Set 6 | yar-sale
# Processing Record 27 of Set 6 | bara
# Processing Record 28 of Set 6 | lorengau
# Processing Record 29 of Set 6 | tiznit
# Processing Record 30 of Set 6 | wajima
# Processing Record 31 of Set 6 | mahebourg
# Processing Record 32 of Set 6 | chaykovskiy
# Processing Record 33 of Set 6 | axim
# Processing Record 34 of Set 6 | pevek
# Processing Record 35 of Set 6 | bonthe
# Processing Record 36 of Set 6 | great yarmouth
# Processing Record 37 of Set 6 | sibolga
# Processing Record 38 of Set 6 | kraslava
# Processing Record 39 of Set 6 | princeton
# Processing Record 40 of Set 6 | yurty
# Processing Record 41 of Set 6 | kedougou
# Processing Record 42 of Set 6 | ucluelet
# Processing Record 43 of Set 6 | hofn
# Processing Record 44 of Set 6 | tamandare
# Processing Record 45 of Set 6 | jhinjhak
# Processing Record 46 of Set 6 | boralday
# Processing Record 47 of Set 6 | vostok
# Processing Record 48 of Set 6 | hay river
# Processing Record 49 of Set 6 | chuy
# Processing Record 50 of Set 6 | andros town
# Processing Record 1 of Set 7 | isangel
# Processing Record 2 of Set 7 | taltal
# Processing Record 3 of Set 7 | prainha
# Processing Record 4 of Set 7 | novyy buh
# Processing Record 5 of Set 7 | kiruna
# Processing Record 6 of Set 7 | buqayq
# City not found. Skipping
# Processing Record 7 of Set 7 | nakasongola
# Processing Record 8 of Set 7 | choix
# Processing Record 9 of Set 7 | basco
# Processing Record 10 of Set 7 | truth or consequences
# Processing Record 11 of Set 7 | soloneshnoye
# Processing Record 12 of Set 7 | shakawe
# Processing Record 13 of Set 7 | elizabeth city
# Processing Record 14 of Set 7 | la ronge
# Processing Record 15 of Set 7 | we
# City not found. Skipping
# Processing Record 16 of Set 7 | sinjar
# Processing Record 17 of Set 7 | gotsu
# Processing Record 18 of Set 7 | palmeira das missoes
# Processing Record 19 of Set 7 | pio ix
# Processing Record 20 of Set 7 | staritsa
# Processing Record 21 of Set 7 | malinovskiy
# Processing Record 22 of Set 7 | boyolangu
# Processing Record 23 of Set 7 | half moon bay
# Processing Record 24 of Set 7 | alanya
# Processing Record 25 of Set 7 | sao joao da barra
# Processing Record 26 of Set 7 | mirandopolis
# Processing Record 27 of Set 7 | arman
# Processing Record 28 of Set 7 | issoire
# Processing Record 29 of Set 7 | fidenza
# Processing Record 30 of Set 7 | hovd
# Processing Record 31 of Set 7 | lolua
# City not found. Skipping
# Processing Record 32 of Set 7 | pocinhos
# Processing Record 33 of Set 7 | abu samrah
# Processing Record 34 of Set 7 | karasjok
# Processing Record 35 of Set 7 | yabelo
# Processing Record 36 of Set 7 | qaanaaq
# Processing Record 37 of Set 7 | haverfordwest
# Processing Record 38 of Set 7 | tarauaca
# Processing Record 39 of Set 7 | saldanha
# Processing Record 40 of Set 7 | cherskiy
# Processing Record 41 of Set 7 | tuatapere
# Processing Record 42 of Set 7 | waipawa
# Processing Record 43 of Set 7 | les cayes
# Processing Record 44 of Set 7 | cessnock
# Processing Record 45 of Set 7 | soyo
# Processing Record 46 of Set 7 | qaqortoq
# Processing Record 47 of Set 7 | umzimvubu
# City not found. Skipping
# Processing Record 48 of Set 7 | srivaikuntam
# Processing Record 49 of Set 7 | gillette
# Processing Record 50 of Set 7 | traverse city
# Processing Record 1 of Set 8 | lagoa
# Processing Record 2 of Set 8 | marinette
# Processing Record 3 of Set 8 | kajiado
# Processing Record 4 of Set 8 | dakoro
# Processing Record 5 of Set 8 | nador
# Processing Record 6 of Set 8 | laguna
# Processing Record 7 of Set 8 | envira
# Processing Record 8 of Set 8 | emerald
# Processing Record 9 of Set 8 | duluth
# Processing Record 10 of Set 8 | dzhusaly
# City not found. Skipping
# Processing Record 11 of Set 8 | carnarvon
# Processing Record 12 of Set 8 | yuncheng
# Processing Record 13 of Set 8 | havelock
# Processing Record 14 of Set 8 | abu dhabi
# Processing Record 15 of Set 8 | havoysund
# Processing Record 16 of Set 8 | vila franca do campo
# Processing Record 17 of Set 8 | yialos
# City not found. Skipping
# Processing Record 18 of Set 8 | umm kaddadah
# Processing Record 19 of Set 8 | kapan
# Processing Record 20 of Set 8 | uruguaiana
# Processing Record 21 of Set 8 | washington
# Processing Record 22 of Set 8 | aklavik
# Processing Record 23 of Set 8 | auki
# Processing Record 24 of Set 8 | artyk
# City not found. Skipping
# Processing Record 25 of Set 8 | kutum
# Processing Record 26 of Set 8 | smithers
# Processing Record 27 of Set 8 | ladario
# Processing Record 28 of Set 8 | huejuquilla el alto
# Processing Record 29 of Set 8 | abha
# Processing Record 30 of Set 8 | maldonado
# Processing Record 31 of Set 8 | pisco
# Processing Record 32 of Set 8 | tucuma
# Processing Record 33 of Set 8 | sangar
# Processing Record 34 of Set 8 | ulundi
# Processing Record 35 of Set 8 | hamilton
# Processing Record 36 of Set 8 | egvekinot
# Processing Record 37 of Set 8 | letka
# Processing Record 38 of Set 8 | broken hill
# Processing Record 39 of Set 8 | hami
# Processing Record 40 of Set 8 | ellisras
# Processing Record 41 of Set 8 | coihaique
# Processing Record 42 of Set 8 | pozo colorado
# Processing Record 43 of Set 8 | bytow
# Processing Record 44 of Set 8 | shetpe
# Processing Record 45 of Set 8 | kalmunai
# Processing Record 46 of Set 8 | ozark
# Processing Record 47 of Set 8 | bengkulu
# Processing Record 48 of Set 8 | bilma
# Processing Record 49 of Set 8 | mansa
# Processing Record 50 of Set 8 | casablanca
# Processing Record 1 of Set 9 | touros
# Processing Record 2 of Set 9 | zonguldak
# Processing Record 3 of Set 9 | rock sound
# Processing Record 4 of Set 9 | gladstone
# Processing Record 5 of Set 9 | canon city
# Processing Record 6 of Set 9 | virginia beach
# Processing Record 7 of Set 9 | puerto del rosario
# Processing Record 8 of Set 9 | denpasar
# Processing Record 9 of Set 9 | nantucket
# Processing Record 10 of Set 9 | nishihara
# Processing Record 11 of Set 9 | tuktoyaktuk
# Processing Record 12 of Set 9 | gimli
# Processing Record 13 of Set 9 | lompoc
# Processing Record 14 of Set 9 | dungarpur
# Processing Record 15 of Set 9 | muriwai beach
# Processing Record 16 of Set 9 | wahran
# City not found. Skipping
# Processing Record 17 of Set 9 | cuenca
# Processing Record 18 of Set 9 | kushima
# Processing Record 19 of Set 9 | aflu
# City not found. Skipping
# Processing Record 20 of Set 9 | araouane
# Processing Record 21 of Set 9 | mount pleasant
# Processing Record 22 of Set 9 | barentsburg
# City not found. Skipping
# Processing Record 23 of Set 9 | kampene
# Processing Record 24 of Set 9 | mangai
# Processing Record 25 of Set 9 | kanchanaburi
# Processing Record 26 of Set 9 | presidente dutra
# Processing Record 27 of Set 9 | beloha
# Processing Record 28 of Set 9 | sabang
# Processing Record 29 of Set 9 | karatau
# Processing Record 30 of Set 9 | dongsheng
# Processing Record 31 of Set 9 | valleyview
# Processing Record 32 of Set 9 | ossora
# Processing Record 33 of Set 9 | mampong
# Processing Record 34 of Set 9 | fukue
# Processing Record 35 of Set 9 | meadow lake
# Processing Record 36 of Set 9 | rocha
# Processing Record 37 of Set 9 | sayabec
# City not found. Skipping
# Processing Record 38 of Set 9 | matara
# Processing Record 39 of Set 9 | fengzhen
# Processing Record 40 of Set 9 | ocean city
# Processing Record 41 of Set 9 | mogok
# Processing Record 42 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 43 of Set 9 | buala
# Processing Record 44 of Set 9 | jumla
# Processing Record 45 of Set 9 | tadine
# Processing Record 46 of Set 9 | lima
# Processing Record 47 of Set 9 | stillwater
# Processing Record 48 of Set 9 | mendahara
# City not found. Skipping
# Processing Record 49 of Set 9 | atar
# Processing Record 50 of Set 9 | imbituba
# Processing Record 1 of Set 10 | hangu
# Processing Record 2 of Set 10 | flinders
# Processing Record 3 of Set 10 | khatanga
# Processing Record 4 of Set 10 | yelizovo
# Processing Record 5 of Set 10 | akdepe
# Processing Record 6 of Set 10 | olga
# Processing Record 7 of Set 10 | arrecife
# Processing Record 8 of Set 10 | pingliang
# Processing Record 9 of Set 10 | golden
# Processing Record 10 of Set 10 | terralba
# Processing Record 11 of Set 10 | grants
# Processing Record 12 of Set 10 | grodzisk wielkopolski
# Processing Record 13 of Set 10 | kaina
# Processing Record 14 of Set 10 | port lincoln
# Processing Record 15 of Set 10 | vila
# Processing Record 16 of Set 10 | chulym
# Processing Record 17 of Set 10 | wyndham
# Processing Record 18 of Set 10 | tyrma
# Processing Record 19 of Set 10 | frutigen
# Processing Record 20 of Set 10 | tiarei
# Processing Record 21 of Set 10 | guiratinga
# Processing Record 22 of Set 10 | glen allen
# Processing Record 23 of Set 10 | okandja
# City not found. Skipping
# Processing Record 24 of Set 10 | batagay
# Processing Record 25 of Set 10 | kaele
# Processing Record 26 of Set 10 | lata
# Processing Record 27 of Set 10 | burnie
# Processing Record 28 of Set 10 | veraval
# Processing Record 29 of Set 10 | huron
# Processing Record 30 of Set 10 | gunnedah
# Processing Record 31 of Set 10 | dickinson
# Processing Record 32 of Set 10 | necochea
# Processing Record 33 of Set 10 | torbay
# Processing Record 34 of Set 10 | gat
# Processing Record 35 of Set 10 | boende
# Processing Record 36 of Set 10 | the valley
# Processing Record 37 of Set 10 | constanza
# Processing Record 38 of Set 10 | hammerfest
# Processing Record 39 of Set 10 | oyamel
# City not found. Skipping
# Processing Record 40 of Set 10 | goundam
# Processing Record 41 of Set 10 | cabedelo
# Processing Record 42 of Set 10 | xalpatlahuac
# Processing Record 43 of Set 10 | bambous virieux
# Processing Record 44 of Set 10 | moron
# Processing Record 45 of Set 10 | high level
# Processing Record 46 of Set 10 | saint-augustin
# Processing Record 47 of Set 10 | northam
# Processing Record 48 of Set 10 | viareggio
# Processing Record 49 of Set 10 | sola
# Processing Record 50 of Set 10 | mitsamiouli
# Processing Record 1 of Set 11 | yeroham
# Processing Record 2 of Set 11 | longlac
# City not found. Skipping
# Processing Record 3 of Set 11 | wenling
# Processing Record 4 of Set 11 | luanda
# Processing Record 5 of Set 11 | doha
# Processing Record 6 of Set 11 | benidorm
# Processing Record 7 of Set 11 | richards bay
# Processing Record 8 of Set 11 | sampit
# Processing Record 9 of Set 11 | ratingen
# Processing Record 10 of Set 11 | creel
# Processing Record 11 of Set 11 | castel san pietro terme
# Processing Record 12 of Set 11 | segezha
# Processing Record 13 of Set 11 | weiser
# Processing Record 14 of Set 11 | ilhabela
# Processing Record 15 of Set 11 | alofi
# Processing Record 16 of Set 11 | caravelas
# Processing Record 17 of Set 11 | gonda
# Processing Record 18 of Set 11 | machali
# Processing Record 19 of Set 11 | chagda
# City not found. Skipping
# Processing Record 20 of Set 11 | ituni
# City not found. Skipping
# Processing Record 21 of Set 11 | barawe
# City not found. Skipping
# Processing Record 22 of Set 11 | ibotirama
# Processing Record 23 of Set 11 | atambua
# Processing Record 24 of Set 11 | tsiroanomandidy
# Processing Record 25 of Set 11 | voyvozh
# Processing Record 26 of Set 11 | shellbrook
# Processing Record 27 of Set 11 | morros
# Processing Record 28 of Set 11 | novosil
# Processing Record 29 of Set 11 | sijunjung
# Processing Record 30 of Set 11 | margate
# Processing Record 31 of Set 11 | yulara
# Processing Record 32 of Set 11 | takoradi
# Processing Record 33 of Set 11 | itoman
# Processing Record 34 of Set 11 | roros
# Processing Record 35 of Set 11 | karaul
# City not found. Skipping
# Processing Record 36 of Set 11 | macia
# Processing Record 37 of Set 11 | san ignacio
# Processing Record 38 of Set 11 | kochi
# Processing Record 39 of Set 11 | pangnirtung
# Processing Record 40 of Set 11 | payo
# Processing Record 41 of Set 11 | mogadishu
# Processing Record 42 of Set 11 | lagos
# Processing Record 43 of Set 11 | huarmey
# Processing Record 44 of Set 11 | leh
# Processing Record 45 of Set 11 | saleaula
# City not found. Skipping
# Processing Record 46 of Set 11 | muret
# Processing Record 47 of Set 11 | pingzhuang
# Processing Record 48 of Set 11 | weihai
# Processing Record 49 of Set 11 | nisia floresta
# Processing Record 50 of Set 11 | oranjestad
# Processing Record 1 of Set 12 | louisbourg
# City not found. Skipping
# Processing Record 2 of Set 12 | tarakan
# Processing Record 3 of Set 12 | rio gallegos
# Processing Record 4 of Set 12 | coahuayana
# Processing Record 5 of Set 12 | tecoanapa
# Processing Record 6 of Set 12 | bani walid
# Processing Record 7 of Set 12 | satitoa
# City not found. Skipping
# Processing Record 8 of Set 12 | tucuman
# Processing Record 9 of Set 12 | kailua
# Processing Record 10 of Set 12 | narsaq
# Processing Record 11 of Set 12 | beberibe
# Processing Record 12 of Set 12 | ullapool
# Processing Record 13 of Set 12 | srandakan
# Processing Record 14 of Set 12 | tecolutla
# Processing Record 15 of Set 12 | asau
# Processing Record 16 of Set 12 | karakol
# Processing Record 17 of Set 12 | viesca
# Processing Record 18 of Set 12 | sao jose da coroa grande
# Processing Record 19 of Set 12 | dali
# Processing Record 20 of Set 12 | clyde river
# Processing Record 21 of Set 12 | metro
# Processing Record 22 of Set 12 | salalah
# Processing Record 23 of Set 12 | iquique
# Processing Record 24 of Set 12 | praia da vitoria
# Processing Record 25 of Set 12 | camana
# Processing Record 26 of Set 12 | roma
# Processing Record 27 of Set 12 | tuggurt
# City not found. Skipping
# Processing Record 28 of Set 12 | celestun
# Processing Record 29 of Set 12 | comodoro rivadavia
# Processing Record 30 of Set 12 | bereznik
# Processing Record 31 of Set 12 | moramanga
# Processing Record 32 of Set 12 | randudongkal
# Processing Record 33 of Set 12 | bouillante
# Processing Record 34 of Set 12 | bargal
# City not found. Skipping
# Processing Record 35 of Set 12 | odesskoye
# Processing Record 36 of Set 12 | yumen
# Processing Record 37 of Set 12 | korla
# Processing Record 38 of Set 12 | kloulklubed
# Processing Record 39 of Set 12 | college
# Processing Record 40 of Set 12 | pueblo nuevo
# Processing Record 41 of Set 12 | geraldton
# Processing Record 42 of Set 12 | tabas
# Processing Record 43 of Set 12 | santiago del estero
# Processing Record 44 of Set 12 | andevoranto
# City not found. Skipping
# Processing Record 45 of Set 12 | burkhala
# City not found. Skipping
# Processing Record 46 of Set 12 | pospelikha
# Processing Record 47 of Set 12 | svetlyy
# Processing Record 48 of Set 12 | xining
# Processing Record 49 of Set 12 | halalo
# City not found. Skipping
# Processing Record 50 of Set 12 | launceston
# Processing Record 1 of Set 13 | nouadhibou
# Processing Record 2 of Set 13 | lokhvytsya
# Processing Record 3 of Set 13 | sai buri
# Processing Record 4 of Set 13 | hazorasp
# Processing Record 5 of Set 13 | tocopilla
# Processing Record 6 of Set 13 | hirara
# Processing Record 7 of Set 13 | el fuerte
# Processing Record 8 of Set 13 | macusani
# Processing Record 9 of Set 13 | eureka
# Processing Record 10 of Set 13 | kifri
# Processing Record 11 of Set 13 | zaplavnoye
# Processing Record 12 of Set 13 | karpathos
# Processing Record 13 of Set 13 | spanish town
# Processing Record 14 of Set 13 | sungairaya
# Processing Record 15 of Set 13 | genhe
# Processing Record 16 of Set 13 | krabi
# Processing Record 17 of Set 13 | belle glade
# Processing Record 18 of Set 13 | elkton
# Processing Record 19 of Set 13 | leningradskiy
# Processing Record 20 of Set 13 | san andres del rabanedo
# Processing Record 21 of Set 13 | oussouye
# Processing Record 22 of Set 13 | buraydah
# Processing Record 23 of Set 13 | kamloops
# Processing Record 24 of Set 13 | grand gaube
# Processing Record 25 of Set 13 | evensk
# Processing Record 26 of Set 13 | kungurtug
# Processing Record 27 of Set 13 | ler
# Processing Record 28 of Set 13 | dabat
# Processing Record 29 of Set 13 | bako
# Processing Record 30 of Set 13 | fort nelson
# Processing Record 31 of Set 13 | arteaga
# Processing Record 32 of Set 13 | jinchang
# Processing Record 33 of Set 13 | vikhorevka
# Processing Record 34 of Set 13 | goure
# Processing Record 35 of Set 13 | kununurra
# Processing Record 36 of Set 13 | lithakia
# Processing Record 37 of Set 13 | honiara
# Processing Record 38 of Set 13 | smirnykh
# Processing Record 39 of Set 13 | alibog
# City not found. Skipping
# Processing Record 40 of Set 13 | zemio
# Processing Record 41 of Set 13 | bacolod
# Processing Record 42 of Set 13 | letterkenny
# Processing Record 43 of Set 13 | anupshahr
# Processing Record 44 of Set 13 | grandview
# Processing Record 45 of Set 13 | neiafu
# Processing Record 46 of Set 13 | sindand
# City not found. Skipping
# Processing Record 47 of Set 13 | nuuk
# Processing Record 48 of Set 13 | taunggyi
# Processing Record 49 of Set 13 | anadyr
# Processing Record 50 of Set 13 | cap malheureux
# Processing Record 1 of Set 14 | azul
# Processing Record 2 of Set 14 | kawalu
# Processing Record 3 of Set 14 | hihifo
# City not found. Skipping
# Processing Record 4 of Set 14 | ostrovnoy
# Processing Record 5 of Set 14 | sept-iles
# Processing Record 6 of Set 14 | karasburg
# Processing Record 7 of Set 14 | kemijarvi
# Processing Record 8 of Set 14 | antsohihy
# Processing Record 9 of Set 14 | saint-georges
# Processing Record 10 of Set 14 | bealanana
# Processing Record 11 of Set 14 | emilio carranza
# Processing Record 12 of Set 14 | aloleng
# Processing Record 13 of Set 14 | san estanislao
# Processing Record 14 of Set 14 | den helder
# Processing Record 15 of Set 14 | upata
# Processing Record 16 of Set 14 | veendam
# Processing Record 17 of Set 14 | isiolo
# Processing Record 18 of Set 14 | kinango
# Processing Record 19 of Set 14 | eyl
# Processing Record 20 of Set 14 | palu
# Processing Record 21 of Set 14 | beringovskiy
# Processing Record 22 of Set 14 | odweyne
# Processing Record 23 of Set 14 | saryshagan
# City not found. Skipping
# Processing Record 24 of Set 14 | twentynine palms
# Processing Record 25 of Set 14 | costinesti
# Processing Record 26 of Set 14 | pilao arcado
# City not found. Skipping
# Processing Record 27 of Set 14 | corning
# Processing Record 28 of Set 14 | yakeshi
# Processing Record 29 of Set 14 | erice
# Processing Record 30 of Set 14 | maningrida
# Processing Record 31 of Set 14 | talaya
# Processing Record 32 of Set 14 | maues
# Processing Record 33 of Set 14 | bembereke
# Processing Record 34 of Set 14 | vestmanna
# Processing Record 35 of Set 14 | la orilla
# Processing Record 36 of Set 14 | minnedosa
# Processing Record 37 of Set 14 | kirtipur
# Processing Record 38 of Set 14 | nizhnyaya tavda
# Processing Record 39 of Set 14 | riberalta
# Processing Record 40 of Set 14 | dosso
# Processing Record 41 of Set 14 | opochka
# Processing Record 42 of Set 14 | ayorou
# Processing Record 43 of Set 14 | jasper
# Processing Record 44 of Set 14 | guapore
# Processing Record 45 of Set 14 | shimsk
# Processing Record 46 of Set 14 | pangody
# Processing Record 47 of Set 14 | port macquarie
# Processing Record 48 of Set 14 | ko samui
# Processing Record 49 of Set 14 | kumukh
# Processing Record 50 of Set 14 | palabuhanratu
# City not found. Skipping
# Processing Record 1 of Set 15 | nioro
# Processing Record 2 of Set 15 | tenkodogo
# Processing Record 3 of Set 15 | shache
# Processing Record 4 of Set 15 | rincon
# Processing Record 5 of Set 15 | hirtshals
# Processing Record 6 of Set 15 | maniitsoq
# Processing Record 7 of Set 15 | banda aceh
# Processing Record 8 of Set 15 | warqla
# City not found. Skipping
# Processing Record 9 of Set 15 | zholymbet
# Processing Record 10 of Set 15 | berlevag
# Processing Record 11 of Set 15 | akhtanizovskaya
# Processing Record 12 of Set 15 | kintinku
# Processing Record 13 of Set 15 | kangaatsiaq
# Processing Record 14 of Set 15 | tommot
# Processing Record 15 of Set 15 | troitsko-pechorsk
# Processing Record 16 of Set 15 | canutama
# Processing Record 17 of Set 15 | seymchan
# Processing Record 18 of Set 15 | tignere
# Processing Record 19 of Set 15 | mucuri
# Processing Record 20 of Set 15 | ugoofaaru
# Processing Record 21 of Set 15 | hunza
# City not found. Skipping
# Processing Record 22 of Set 15 | luzhou
# Processing Record 23 of Set 15 | sedelnikovo
# City not found. Skipping
# Processing Record 24 of Set 15 | awash
# Processing Record 25 of Set 15 | teya
# Processing Record 26 of Set 15 | marshall
# Processing Record 27 of Set 15 | canatlan
# Processing Record 28 of Set 15 | port said
# Processing Record 29 of Set 15 | marystown
# Processing Record 30 of Set 15 | uyuni
# Processing Record 31 of Set 15 | burica
# City not found. Skipping
# Processing Record 32 of Set 15 | dawei
# Processing Record 33 of Set 15 | goba
# Processing Record 34 of Set 15 | santa isabel do rio negro
# Processing Record 35 of Set 15 | kiama
# Processing Record 36 of Set 15 | one hundred mile house
# City not found. Skipping
# Processing Record 37 of Set 15 | colac
# Processing Record 38 of Set 15 | srednekolymsk
# Processing Record 39 of Set 15 | stornoway
# Processing Record 40 of Set 15 | moerai
# Processing Record 41 of Set 15 | alta floresta
# Processing Record 42 of Set 15 | roura
# Processing Record 43 of Set 15 | zhangye
# Processing Record 44 of Set 15 | williamsport
# Processing Record 45 of Set 15 | raudeberg
# Processing Record 46 of Set 15 | wasilla
# Processing Record 47 of Set 15 | galiwinku
# City not found. Skipping
# Processing Record 48 of Set 15 | rosetta
# Processing Record 49 of Set 15 | barra do bugres
# Processing Record 50 of Set 15 | komsomolskiy
# Processing Record 1 of Set 16 | qasigiannguit
# Processing Record 2 of Set 16 | cuamba
# Processing Record 3 of Set 16 | felidhoo
# City not found. Skipping
# Processing Record 4 of Set 16 | ponnani
# Processing Record 5 of Set 16 | calgary
# Processing Record 6 of Set 16 | mormugao
# Processing Record 7 of Set 16 | upington
# Processing Record 8 of Set 16 | korsakov
# Processing Record 9 of Set 16 | tabukiniberu
# City not found. Skipping
# Processing Record 10 of Set 16 | kongoussi
# Processing Record 11 of Set 16 | bouafle
# Processing Record 12 of Set 16 | whyalla
# Processing Record 13 of Set 16 | fairlie
# Processing Record 14 of Set 16 | itaporanga
# Processing Record 15 of Set 16 | gorom-gorom
# Processing Record 16 of Set 16 | montepuez
# Processing Record 17 of Set 16 | quatre cocos
# Processing Record 18 of Set 16 | reconquista
# Processing Record 19 of Set 16 | santa catarina de tepehuanes
# Processing Record 20 of Set 16 | natitingou
# Processing Record 21 of Set 16 | srikakulam
# Processing Record 22 of Set 16 | baykit
# Processing Record 23 of Set 16 | japura
# Processing Record 24 of Set 16 | porto novo
# Processing Record 25 of Set 16 | ondorhaan
# City not found. Skipping
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country                 Date      Lat       Lng  Max Temp  \
# 0       Upernavik      GL  2022-08-25 00:11:51  72.7868  -56.1549     40.86
# 1         Ushuaia      AR  2022-08-25 00:16:43 -54.8000  -68.3000     42.46
# 2  Cabo San Lucas      MX  2022-08-25 00:12:27  22.8909 -109.9124     91.18
# 3        Penzance      GB  2022-08-25 00:16:44  50.1186   -5.5371     59.68
# 4    Krasnoselkup      RU  2022-08-25 00:16:45  65.7000   82.4667     51.51
# 5         Kavieng      PG  2022-08-25 00:16:45  -2.5744  150.7967     82.98
# 6        Victoria      HK  2022-08-25 00:15:10  22.2855  114.1577     82.45
# 7       Busselton      AU  2022-08-25 00:10:40 -33.6500  115.3333     53.13
# 8         Paamiut      GL  2022-08-25 00:16:46  61.9940  -49.6678     41.99
# 9         Rikitea      PF  2022-08-25 00:16:47 -23.1203 -134.9692     69.21
#
#    Humidity  Cloudiness  Wind Speed Current Description
# 0        82          64       10.40       broken clouds
# 1        42          20       11.50          few clouds
# 2        62          20       19.57          few clouds
# 3        72         100       14.61     overcast clouds
# 4        82          18       19.10          few clouds
# 5        73          29        5.75    scattered clouds
# 6        92          92       14.00          light rain
# 7        66          98        6.04     overcast clouds
# 8        99         100        8.28     overcast clouds
# 9        66          80       16.89       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
